# %%
! pip install google-genai
# Out:
# Collecting google-genai
#   Downloading google_genai-1.63.0-py3-none-any.whl.metadata (53 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in .\.env_gemini_groq_inference\Lib\site-packages (from google-genai) (4.12.1)
# Collecting google-auth<3.0.0,>=2.47.0 (from google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Downloading google_auth-2.48.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in .\.env_gemini_groq_inference\Lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in .\.env_gemini_groq_inference\Lib\site-packages (from google-genai) (2.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in .\.env_gemini_groq_inference\Lib\site-packages (from google-genai) (2.32.5)
# Collecting tenacity<9.2.0,>=8.2.3 (from google-genai)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting websockets<15.1.0,>=13.0.0 (from google-genai)
#   Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in .\.env_gemini_groq_inference\Lib\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in .\.env_gemini_groq_inference\Lib\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in .\.env_gemini_groq_inference\Lib\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in .\.env_gemini_groq_inference\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting cryptography>=38.0.3 (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Downloading cryptography-46.0.5-cp311-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: certifi in .\.env_gemini_groq_inference\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in .\.env_gemini_groq_inference\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\.env_gemini_groq_inference\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\.env_gemini_groq_inference\Lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\.env_gemini_groq_inference\Lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\.env_gemini_groq_inference\Lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.env_gemini_groq_inference\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\.env_gemini_groq_inference\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.6.3)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Using cached pyasn1-0.6.2-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: cffi>=2.0.0 in .\.env_gemini_groq_inference\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in .\.env_gemini_groq_inference\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (3.0)
# Downloading google_genai-1.63.0-py3-none-any.whl (724 kB)
#    ---------------------------------------- 0.0/724.7 kB ? eta -:--:--
#    ---------------------------------------- 724.7/724.7 kB 3.7 MB/s  0:00:00
# Downloading google_auth-2.48.0-py3-none-any.whl (236 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Downloading cryptography-46.0.5-cp311-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    --------- ------------------------------ 0.8/3.5 MB 4.8 MB/s eta 0:00:01
#    ------------------ --------------------- 1.6/3.5 MB 3.5 MB/s eta 0:00:01
#    --------------------------- ------------ 2.4/3.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  3.4/3.5 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 4.0 MB/s  0:00:00
# Using cached pyasn1-0.6.2-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Installing collected packages: websockets, tenacity, pyasn1, rsa, pyasn1-modules, cryptography, google-auth, google-genai
#
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
#    ---------------------------------------- 0/8 [websockets]
#    ----- ---------------------------------- 1/8 [tenacity]
#    ---------- ----------------------------- 2/8 [pyasn1]
#    ---------- ----------------------------- 2/8 [pyasn1]
#    ---------- ----------------------------- 2/8 [pyasn1]
#    --------------- ------------------------ 3/8 [rsa]
#    --------------- ------------------------ 3/8 [rsa]
#    --------------- ------------------------ 3/8 [rsa]
#    --------------- ------------------------ 3/8 [rsa]
#    -------------------- ------------------- 4/8 [pyasn1-modules]
#    -------------------- ------------------- 4/8 [pyasn1-modules]
#    -------------------- ------------------- 4/8 [pyasn1-modules]
#    -------------------- ------------------- 4/8 [pyasn1-modules]
#    -------------------- ------------------- 4/8 [pyasn1-modules]
#    -------------------- ------------------- 4/8 [pyasn1-modules]
#    -------------------- ------------------- 4/8 [pyasn1-modules]
#    -------------------- ------------------- 4/8 [pyasn1-modules]
#    -------------------- ------------------- 4/8 [pyasn1-modules]
#    -------------------- ------------------- 4/8 [pyasn1-modules]
#    -------------------- ------------------- 4/8 [pyasn1-modules]
#    -------------------- ------------------- 4/8 [pyasn1-modules]
#    ------------------------- -------------- 5/8 [cryptography]
#    ------------------------- -------------- 5/8 [cryptography]
#    ------------------------- -------------- 5/8 [cryptography]
#    ------------------------- -------------- 5/8 [cryptography]
#    ------------------------- -------------- 5/8 [cryptography]
#    ------------------------- -------------- 5/8 [cryptography]
#    ------------------------- -------------- 5/8 [cryptography]
#    ------------------------------ --------- 6/8 [google-auth]
#    ------------------------------ --------- 6/8 [google-auth]
#    ------------------------------ --------- 6/8 [google-auth]
#    ------------------------------ --------- 6/8 [google-auth]
#    ------------------------------ --------- 6/8 [google-auth]
#    ------------------------------ --------- 6/8 [google-auth]
#    ------------------------------ --------- 6/8 [google-auth]
#    ------------------------------ --------- 6/8 [google-auth]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ----------------------------------- ---- 7/8 [google-genai]
#    ---------------------------------------- 8/8 [google-genai]
#
# Successfully installed cryptography-46.0.5 google-auth-2.48.0 google-genai-1.63.0 pyasn1-0.6.2 pyasn1-modules-0.4.2 rsa-4.9.1 tenacity-9.1.4 websockets-15.0.1

# %%
from google import genai
from google.genai import types
client = genai.Client(api_key="AIzaSyDjXKZ5l7wnK1ffceiuh8dO92e6o1BfaJg")

with open('image.JPG', 'rb') as f:
  image_bytes = f.read()

context = [
    types.Part.from_bytes(
        data=image_bytes,
        mime_type='image/jpeg',
    ),
]

response = client.models.generate_content(
    model="gemini-3-flash-preview",    
    contents=context,   
)

print(response.text)
# Out:
# Based on the image provided, here is a detailed description and the information extracted:
#
# ### **Location**
# The image was taken at **Manchester Piccadilly Station** in England. This is identified by the text on the back of the high-visibility vest worn by the staff member in the center of the image.
#
# ### **The Scene**
# The scene depicts a busy railway platform under a large, arched industrial-style metal roof. Passengers are in the process of boarding a modern, dark grey or black train.
#
# ### **Key Details**
# *   **The Train:** The train is dark in color with large windows. Above the open door, there is a purple sign featuring four white accessibility icons (representing wheelchair access, etc.). Partial text "www.t..." is visible on the lower right side of the carriage.
# *   **Station Staff:** A staff member wearing a blue uniform with a high-visibility panel is assisting an elderly passenger with white hair onto the train.
# *   **Passengers and Luggage:**
#     *   In the foreground, a man in a black hoodie and green shorts stands with a large black backpack and a silver suitcase.
#     *   A woman in a turquoise jacket is seen with a bright pink suitcase.
#     *   On the far left, a man in a grey jacket stands next to a yellow suitcase.
#     *   In the center, a woman in a tan coat carries a black bag with the text **"THE TOTE BAG MARC JACOBS"** clearly visible.
# *   **Infrastructure:** The platform features standard safety markings, including a yellow line and tactile paving near the edge. The station's architecture is characterized by its large, intricate metal lattice roof.
#
# ### **Atmosphere**
# The image captures a typical, busy moment of travel, highlighting the boarding process and the assistance provided to passengers with mobility needs.

# %%
response = client.models.generate_content(
    model="gemini-3-flash-preview",    
    contents=context,
    config=types.GenerateContentConfig(
        system_instruction="You are a helpful AI assistant. "
                           "Given an image, perform object detection and "
                           "provide a text output that contains the labels detected and their counts."),
    
)

print(response.text)
# Out:
# This image features 15 persons, 4 suitcases, 2 handbags, 1 backpack, and 1 train.
